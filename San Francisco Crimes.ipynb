# %%
# SAN FRANCISCO CRIMES ANALYSIS

Views:
1 Crimes por categoria (qtdd)
  Crimes por bairro (qtdd)
  Crimes por tipo (qtdd)
  Crimes por semana (qtdd)
  Taxa de solução por crime (prisão)
  Crimes por horário e bairro (qtdd)
  Crimes por rua e horário

# %% [markdown]
# # Importando a base

# %%
import pandas as pd

# %%
ls
# Out:
#  O volume na unidade C nÆo tem nome.
#  O N£mero de S‚rie do Volume ‚ 8285-26B3
#
#  Pasta de C:\Users\scarlet\Projetos Python\San Francisco Crimes
#
# 21/11/2022  22:16    <DIR>          .
# 21/11/2022  22:16    <DIR>          ..
# 21/11/2022  21:01    <DIR>          .ipynb_checkpoints
# 21/11/2022  22:16            13.499 San Francisco Crimes.ipynb
#                1 arquivo(s)         13.499 bytes
#                3 pasta(s)   27.288.162.304 bytes dispon¡veis

# %%
dados = pd.read_csv('crime.csv')
dados
# Out:
#         IncidntNum        Category  \
# 0        120058272     WEAPON LAWS
# 1        120058272     WEAPON LAWS
# 2        141059263        WARRANTS
# 3        160013662    NON-CRIMINAL
# 4        160002740    NON-CRIMINAL
# ...            ...             ...
# 150495   161061000         ASSAULT
# 150496   176000742    NON-CRIMINAL
# 150497   176000758   LARCENY/THEFT
# 150498   176000764   LARCENY/THEFT
# 150499   179002868  OTHER OFFENSES
#
#                                                  Descript DayOfWeek  \
# 0                               POSS OF PROHIBITED WEAPON    Friday
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                          WARRANT ARREST    Monday
# 3                                           LOST PROPERTY   Tuesday
# 4                                           LOST PROPERTY    Friday
# ...                                                   ...       ...
# ...

# %%
dados.shape
# Out:
# (150500, 13)

# %%
dados.info
# Out:
# <bound method DataFrame.info of         IncidntNum        Category  \
# 0        120058272     WEAPON LAWS
# 1        120058272     WEAPON LAWS
# 2        141059263        WARRANTS
# 3        160013662    NON-CRIMINAL
# 4        160002740    NON-CRIMINAL
# ...            ...             ...
# 150495   161061000         ASSAULT
# 150496   176000742    NON-CRIMINAL
# 150497   176000758   LARCENY/THEFT
# 150498   176000764   LARCENY/THEFT
# 150499   179002868  OTHER OFFENSES
#
#                                                  Descript DayOfWeek  \
# 0                               POSS OF PROHIBITED WEAPON    Friday
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                          WARRANT ARREST    Monday
# 3                                           LOST PROPERTY   Tuesday
# 4                                           LOST PROPERTY    Friday
# ...                                                   ...       ...
# ...

# %%
dados.dtypes
# Out:
# IncidntNum      int64
# Category       object
# Descript       object
# DayOfWeek      object
# Date           object
# Time           object
# PdDistrict     object
# Resolution     object
# Address        object
# X             float64
# Y             float64
# Location       object
# PdId            int64
# dtype: object

# %%
(dados[['Category', 'IncidntNum']].groupby('IncidntNum'))

# %%
crime_types = pd.DataFrame(dados['Category'].unique())
crime_types
# Out:
#                               0
# 0                   WEAPON LAWS
# 1                      WARRANTS
# 2                  NON-CRIMINAL
# 3                       ASSAULT
# 4                OTHER OFFENSES
# 5                MISSING PERSON
# 6                 LARCENY/THEFT
# 7                      BURGLARY
# 8               STOLEN PROPERTY
# 9                       ROBBERY
# 10                        FRAUD
# 11                DRUG/NARCOTIC
# 12                VEHICLE THEFT
# 13            RECOVERED VEHICLE
# 14                    VANDALISM
# 15                        ARSON
# 16                 PROSTITUTION
# 17              SECONDARY CODES
# 18               SUSPICIOUS OCC
# 19                  DRUNKENNESS
# 20                     TRESPASS
# 21   SEX OFFENSES, NON FORCIBLE
# 22       SEX OFFENSES, FORCIBLE
# 23                      RUNAWAY
# 24                   KIDNAPPING
# 25           DISORDERLY CONDUCT
# 26  DRIVING UNDER THE INFLUENCE
# 27       FORGERY/COUNTERFEITING
# ...
